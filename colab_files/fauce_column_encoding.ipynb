# %%
# prompt: git clone a branch of a specific git repo

# !git clone -b dverma/update_fauce https://github.com/vermadivyanshu/vldb2021_fauce.git
# Out:
# Cloning into 'vldb2021_fauce'...
# remote: Enumerating objects: 480, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 480 (delta 14), reused 24 (delta 12), pack-reused 442
# Receiving objects: 100% (480/480), 4.20 MiB | 7.31 MiB/s, done.
# Resolving deltas: 100% (234/234), done.

# %%
# !git clone -b dverma/update_environment  https://github.com/vermadivyanshu/neurocard.git
# Out:
# Cloning into 'neurocard'...
# remote: Enumerating objects: 67, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 67 (delta 2), reused 2 (delta 1), pack-reused 60
# Receiving objects: 100% (67/67), 53.44 MiB | 25.22 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %%
# !apt install build-essential
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
# !conda install --channel defaults conda --yes
# !conda update --channel defaults --all --yes
# !cd neurocard && conda env create -f environment.yml

# %%
# !chmod +x neurocard/neurocard/scripts/download_imdb.sh
