# %% [markdown]
# # Clone Github project

# %%
# !rm -rf neurocard

# %%
# !git config --global user.email ericsun42@outlook.com
# !git config --global user.name Erostrate9

# !mkdir /root/.ssh && cp /content/drive/MyDrive/ssh/id_rsa.pub  /root/.ssh/id_rsa.pub
# !cp /content/drive/MyDrive/ssh/id_rsa  /root/.ssh/id_rsa
# !ssh-keygen -t rsa -b 4096 -C "erostrate9@github.com"
# !cat "/root/.ssh/id_rsa.pub"
# !ssh-keyscan github.com >> "/content/drive/My Drive/ssh/known_hosts"
# !mkdir -p /root/.ssh && cp -r "/content/drive/My Drive/ssh/." /root/.ssh/

# %%
# !ssh -T git@github.com
# Out:
# Hi Erostrate9! You've successfully authenticated, but GitHub does not provide shell access.

# %%
# !git clone -b eric git@github.com:Erostrate9/neurocard.git
# Out:
# Cloning into 'neurocard'...
# remote: Enumerating objects: 76, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 76 (delta 7), reused 9 (delta 4), pack-reused 60 (from 1)
# Receiving objects: 100% (76/76), 53.45 MiB | 39.23 MiB/s, done.
# Resolving deltas: 100% (8/8), done.

# %% [markdown]
# ## update github repository

# %%
# %%bash
# cp /"content/drive/MyDrive/Colab Notebooks/neurocard.ipynb" neurocard/neurocard.ipynb
# cd neurocard
# cat .gitignore
# git add .
# git status  # 检查是否已成功添加
# git commit -m "upload colab ipynb file"
# git push origin eric
# Out:
# **/*.pyc
# *.png
# models/epoch-*
# .ipynb*
# __pycache__
# datasets
#
# models/*
# datasets/*
# *.log
#
# **/.DS_Store
# **/*.swp
#
# # Latex tmp files.
# **/*.aux
# **/*.fdb_latexmk
# **/texput.fls
# On branch eric
# Your branch is up to date with 'origin/eric'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   neurocard.ipynb
#
# [eric 4119b42] upload colab ipynb file
#  1 file changed, 1 insertion(+)
#  create mode 100644 neurocard.ipynb
# To github.com:Erostrate9/neurocard.git
#    5bf4f10..4119b42  eric -> eric

# %% [markdown]
# # Install environment

# %%
# !apt install build-essential
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
# !conda install --channel defaults conda --yes
# !conda update --channel defaults --all --yes

# %%
# !conda env remove -n neurocard -y

# %%
# !cd neurocard && conda env create -f environment.yml

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !source activate neurocard && python --version
# Out:
# Python 3.7.7

# %% [markdown]
# # Download dataset

# %%
# !chmod +x neurocard/neurocard/scripts/download_imdb.sh

# %%
# !neurocard/neurocard/scripts/download_imdb.sh
# Out:
# + mkdir -p datasets/job
# + pushd datasets/job
# /content/datasets/job /content
# + wget -c http://homepages.cwi.nl/~boncz/job/imdb.tgz
# --2024-08-12 23:37:08--  http://homepages.cwi.nl/~boncz/job/imdb.tgz
# Resolving homepages.cwi.nl (homepages.cwi.nl)... 192.16.191.44
# Connecting to homepages.cwi.nl (homepages.cwi.nl)|192.16.191.44|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://homepages.cwi.nl/~boncz/job/imdb.tgz [following]
# --2024-08-12 23:37:08--  https://homepages.cwi.nl/~boncz/job/imdb.tgz
# Connecting to homepages.cwi.nl (homepages.cwi.nl)|192.16.191.44|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1263193115 (1.2G) [application/x-gzip]
# Saving to: ‘imdb.tgz’
#
# imdb.tgz            100%[===================>]   1.18G  33.0MB/s    in 38s
#
# 2024-08-12 23:37:47 (31.8 MB/s) - ‘imdb.tgz’ saved [1263193115/1263193115]
#
# + tar -xvzf imdb.tgz
# aka_name.csv
# aka_title.csv
# cast_info.csv
# ...

# %% [markdown]
# # Configure Postgres

# %%
# !sudo apt-get -y -qq install postgresql

# %%
# !sudo service postgresql start
# Out:
#  * Starting PostgreSQL 14 database server
#    ...done.

# %%
# !sudo -u postgres psql -U postgres -c "CREATE ROLE root WITH SUPERUSER;"
# !sudo -u postgres psql -U postgres -c "ALTER ROLE root WITH LOGIN;"
# Out:
# CREATE ROLE
# ALTER ROLE

# %%
# Setup a password `postgres` for username `postgres`
# !sudo -u postgres psql -U postgres -c "ALTER USER postgres PASSWORD 'postgres';"
# Out:
# ALTER ROLE

# %%
# Setup a database with name `imdb` to be used
# !sudo -u postgres psql -U postgres -c 'DROP DATABASE IF EXISTS imdb;'
# !sudo -u postgres psql -U postgres -c 'CREATE DATABASE imdb;'
# Out:
# NOTICE:  database "imdb" does not exist, skipping
# DROP DATABASE
# CREATE DATABASE

# %% [markdown]
# ## Load Data from csv

# %%
# !psql -d imdb -f /content/datasets/job/schematext.sql
# Out:
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE

# %%
# !psql -d imdb -c "COPY title FROM '/content/datasets/job/title.csv' WITH (FORMAT csv, DELIMITER ',', QUOTE '\"', ESCAPE '\\')";
# !psql -d imdb -c "COPY cast_info FROM '/content/datasets/job/cast_info.csv' WITH (FORMAT csv, DELIMITER ',', QUOTE '\"', ESCAPE '\\')";
# !psql -d imdb -c "COPY movie_keyword FROM '/content/datasets/job/movie_keyword.csv' WITH (FORMAT csv, DELIMITER ',', QUOTE '\"', ESCAPE '\\')";
# !psql -d imdb -c "COPY movie_companies FROM '/content/datasets/job/movie_companies.csv' WITH (FORMAT csv, DELIMITER ',', QUOTE '\"', ESCAPE '\\')";
# !psql -d imdb -c "COPY movie_info FROM '/content/datasets/job/movie_info.csv' WITH (FORMAT csv, DELIMITER ',', QUOTE '\"', ESCAPE '\\')"
# !psql -d imdb -c "COPY movie_info_idx FROM '/content/datasets/job/movie_info_idx.csv' WITH (FORMAT csv, DELIMITER ',', QUOTE '\"', ESCAPE '\\')"
# !psql -d imdb -c "COPY comp_cast_type FROM '/content/datasets/job/comp_cast_type.csv' WITH (FORMAT csv, DELIMITER ',', QUOTE '\"', ESCAPE '\\')"
# !psql -d imdb -c "COPY aka_name FROM '/content/datasets/job/aka_name.csv' WITH (FORMAT csv, DELIMITER ',', QUOTE '\"', ESCAPE '\\')"
# !psql -d imdb -c "COPY name FROM '/content/datasets/job/name.csv' WITH (FORMAT csv, DELIMITER ',', QUOTE '\"', ESCAPE '\\')"
# Out:
# COPY 2528312
# COPY 36244344
# COPY 4523930
# COPY 2609129
# COPY 14835720
# COPY 1380035
# COPY 4
# COPY 901343
# COPY 4167491

# %%
# !source activate neurocard && python neurocard/neurocard/scripts/prepend_imdb_headers.py
# Out:
# I0813 00:05:24.000617 132933532542784 prepend_imdb_headers.py:76] Prepending header to datasets/job/aka_name.csv: id,person_id,name,imdb_index,name_pcode_cf,name_pcode_nf,surname_pcode,md5sum
# I0813 00:05:24.739944 132933532542784 prepend_imdb_headers.py:76] Prepending header to datasets/job/aka_title.csv: id,movie_id,title,imdb_index,kind_id,production_year,phonetic_code,episode_of_id,season_nr,episode_nr,note,md5sum
# I0813 00:05:25.013499 132933532542784 prepend_imdb_headers.py:76] Prepending header to datasets/job/cast_info.csv: id,person_id,movie_id,person_role_id,note,nr_order,role_id
# I0813 00:05:39.330459 132933532542784 prepend_imdb_headers.py:76] Prepending header to datasets/job/char_name.csv: id,name,imdb_index,imdb_id,name_pcode_nf,surname_pcode,md5sum
# I0813 00:05:41.136569 132933532542784 prepend_imdb_headers.py:76] Prepending header to datasets/job/company_name.csv: id,name,country_code,imdb_id,name_pcode_nf,name_pcode_sf,md5sum
# ...

# %% [markdown]
# ## Load Data from dump file (Option)

# %%
# !cp imdb_schema_backup.dump /content/drive/MyDrive/imdb_schema_backup.dump
# !cp imdb_data_backup.dump /content/drive/MyDrive/imdb_data_backup.dump
# !pg_dump -d imdb -s -F c -f imdb_schema_backup.dump
# !pg_dump -d imdb -a -F c -f imdb_data_backup.dump
# Out:
# cp: cannot stat 'imdb_schema_backup.dump': No such file or directory
# cp: cannot stat 'imdb_data_backup.dump': No such file or directory

# %%
# !cp /content/drive/MyDrive/imdb_schema_backup.dump /content/imdb_schema_backup.dump
# !cp /content/drive/MyDrive/imdb_data_backup.dump /content/imdb_data_backup.dump
# !pg_restore -d imdb -F c /content/imdb_schema_backup.dump
# !pg_restore -d imdb -F c /content/imdb_data_backup.dump

# %% [markdown]
# ## Test Postgres usability

# %%
# %%bash
# psql -d imdb -c "SELECT COUNT(*) FROM movie_companies, movie_info_idx, title \
# WHERE title.id=movie_companies.movie_id AND movie_companies.movie_id=movie_info_idx.movie_id \
# AND title.series_years <= '2007-????' AND title.phonetic_code <= 'D5316' AND movie_companies.company_type_id = 2 AND title.kind_id = 2;"
# Out:
#  count
# -------
#  27984
# (1 row)

# %% [markdown]
# # Generate queries using Neurocard's package

# %%
# !mkdir output

# %%
# !source activate neurocard && python neurocard/neurocard/make_job_queries.py --job_light_csv /content/neurocard/neurocard/queries/job-light.csv --output_csv output/job-light-simple-1000.csv --num_queries 100
# !cp output/job-light.csv /content/drive/MyDrive/job-light-1.csv
# Out:
# Loaded parsed Table from ./datasets/job/movie_info_idx.info_type_id-movie_id.table
# movie_info_idx([Column(info_type_id, distribution_size=5), Column(movie_id, distribution_size=459925)])
# Loaded parsed Table from ./datasets/job/movie_companies.company_id-company_type_id-movie_id.table
# movie_companies([Column(company_id, distribution_size=234997), Column(company_type_id, distribution_size=2), Column(movie_id, distribution_size=1087236)])
# Loaded parsed Table from ./datasets/job/title.id-kind_id-production_year.table
# title([Column(id, distribution_size=2528312), Column(kind_id, distribution_size=7), Column(production_year, distribution_size=133)])
# Loaded parsed Table from ./datasets/job/cast_info.movie_id-role_id.table
# cast_info([Column(movie_id, distribution_size=2331601), Column(role_id, distribution_size=11)])
# Loaded parsed Table from ./datasets/job/movie_keyword.movie_id-keyword_id.table
# ...

# %%
# !cp output/job-light-simple-1000.csv /content/drive/MyDrive/job-light-simple-100.csv

# %%
# !source activate neurocard && python neurocard/neurocard/make_job_queries.py --job_light_csv /content/neurocard/neurocard/queries/job-light.csv --output_csv output/job-light-content-100.csv --num_queries 100 --use_cols content
# !cp output/job-light-content-100.csv /content/drive/MyDrive/job-light-content-100.csv
# Out:
# FLAGS.use_cols content
# Loaded parsed Table from ./datasets/job/movie_info_idx.info_type_id-movie_id.table
# movie_info_idx([Column(info_type_id, distribution_size=5), Column(movie_id, distribution_size=459925)])
# Loading csv... done, took 0.6s
# Parsing... done, took 0.2s
# Saved parsed Table to ./datasets/job/movie_companies.company_type_id-movie_id.table
# Loading csv... done, took 1.1s
# Parsing... done, took 0.4s
# Saved parsed Table to ./datasets/job/title.production_year-kind_id-id.table
# Loading csv... done, took 16.2s
# Parsing... done, took 19.1s
# Saved parsed Table to ./datasets/job/cast_info.table
# Loading csv... done, took 1.0s
# Parsing... done, took 0.5s
# Saved parsed Table to ./datasets/job/movie_keyword.keyword_id-movie_id.table
# Loading csv... done, took 7.9s
# Parsing... done, took 1.7s
# Saved parsed Table to ./datasets/job/movie_info.info_type_id-movie_id.table
# Loading csv... done, took 0.0s
# Parsing... done, took 0.0s
# ...

# %%
# !source activate neurocard && python neurocard/neurocard/make_job_queries.py --job_light_csv /content/neurocard/neurocard/queries/job-light.csv --output_csv output/job-light-simple-1000.csv --num_queries 1000 --use_cols simple
# !cp output/job-light-simple-1000.csv /content/drive/MyDrive/job-light-simple-1000.csv
# Out:
# FLAGS.use_cols simple
# Loaded parsed Table from ./datasets/job/movie_info_idx.info_type_id-movie_id.table
# movie_info_idx([Column(info_type_id, distribution_size=5), Column(movie_id, distribution_size=459925)])
# Loaded parsed Table from ./datasets/job/movie_companies.company_id-company_type_id-movie_id.table
# movie_companies([Column(company_id, distribution_size=234997), Column(company_type_id, distribution_size=2), Column(movie_id, distribution_size=1087236)])
# Loaded parsed Table from ./datasets/job/title.id-kind_id-production_year.table
# title([Column(id, distribution_size=2528312), Column(kind_id, distribution_size=7), Column(production_year, distribution_size=133)])
# Loaded parsed Table from ./datasets/job/cast_info.movie_id-role_id.table
# cast_info([Column(movie_id, distribution_size=2331601), Column(role_id, distribution_size=11)])
# Loaded parsed Table from ./datasets/job/movie_keyword.movie_id-keyword_id.table
# ...

# %%
# !source activate neurocard && python neurocard/neurocard/make_job_queries.py --job_light_csv /content/neurocard/neurocard/queries/job-light.csv --output_csv output/job-light-content-1000.csv --num_queries 1000 --use_cols content
# !cp output/job-light-content-1000.csv /content/drive/MyDrive/job-light-content-1000.csv
# Out:
# FLAGS.use_cols content
# Loaded parsed Table from ./datasets/job/movie_info_idx.info_type_id-movie_id.table
# movie_info_idx([Column(info_type_id, distribution_size=5), Column(movie_id, distribution_size=459925)])
# Loaded parsed Table from ./datasets/job/movie_companies.company_type_id-movie_id.table
# movie_companies([Column(company_type_id, distribution_size=2), Column(movie_id, distribution_size=1087236)])
# Loaded parsed Table from ./datasets/job/title.production_year-kind_id-id.table
# title([Column(production_year, distribution_size=133), Column(kind_id, distribution_size=7), Column(id, distribution_size=2528312)])
# Loaded parsed Table from ./datasets/job/cast_info.table
# ...

# %%
# !source activate neurocard && python neurocard/neurocard/make_job_queries.py --job_light_csv /content/neurocard/neurocard/queries/job-light.csv --output_csv output/job-light-content-2500.csv --num_queries 2500 --use_cols content
# !cp output/job-light-content-2500.csv /content/drive/MyDrive/job-light-content-2500.csv
# Out:
# Streaming output truncated to the last 5000 lines.
#   Query 16 out of 138 [title.kind_id,=,1.0,movie_info_idx.info_type_id,=,99.0,movie_companies.company_type_id,=,1.0]...done: 38138485 (inner join sel 0.2149997034475963; full sel 1.7914835328974538e-05; inner join 177388547); dur 7.2s
#   Query 17 out of 138 [title.kind_id,=,2.0,movie_companies.company_type_id,=,1.0,movie_info.info_type_id,=,95.0,title.production_year,=,1986.0,movie_info_idx.info_type_id,=,99.0]...done: 52 (inner join sel 2.9314181146091694e-07; full sel 2.4426021041650606e-11; inner join 177388547); dur 1.4s
#   Query 18 out of 138 [title.production_year,=,1993.0,title.kind_id,=,1.0,movie_info_idx.info_type_id,=,101.0]...done: 701004 (inner join sel 0.003951799661564396; full sel 3.292834318131008e-07; inner join 177388547); dur 3.1s
# ...

# %%
# !mkdir neurocard/output_csv
# !cp /content/drive/MyDrive/job-light-content-2500.csv neurocard/output_csv/job-light-content-2500.csv
# !cp /content/drive/MyDrive/job-light-content-700.csv neurocard/output_csv/job-light-content-700.csv
# !cp /content/drive/MyDrive/job-light-simple-30.csv neurocard/output_csv/job-light-simple-30.csv
